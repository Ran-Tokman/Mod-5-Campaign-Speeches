# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
import seaborn as sns
import string
import re
from collections import Counter
import matplotlib.pyplot as plt

# %%
text = """When learning data science, you shouldn't get discouraged!
Challenges and setbacks aren't failures, they're just part of the journey. You've got this!"""

# %%
#  "nlp" Object is used to create documents with linguistic annotations.
my_doc=nlp(text)

# %%
# Create list of word tokens
token_list = []
for token in my_doc:
    token_list.append(token.text)
print(token_list)
# Out:
# ['When', 'learning', 'data', 'science', ',', 'you', 'should', "n't", 'get', 'discouraged', '!', '\n', 'Challenges', 'and', 'setbacks', 'are', "n't", 'failures', ',', 'they', "'re", 'just', 'part', 'of', 'the', 'journey', '.', 'You', "'ve", 'got', 'this', '!']

# %%
# Stop words

# importing stop words from English language.
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %%
#Printing the total number of stop words:
print('Number of stop words: %d' % len(spacy_stopwords))
# Out:
# Number of stop words: 326

# %%
#Printing first ten stop words:
print('First ten stop words: %s' % list(spacy_stopwords)[:20])
# Out:
# First ten stop words: ['herein', 'though', 'both', 'wherein', 'might', 'his', 'was', 'keep', 'us', 'either', 'made', '‘ve', 'by', 'amount', 'whom', 'if', 'somehow', 'which', 'also', 'yours']

# %%
from spacy.lang.en.stop_words import STOP_WORDS

#Implementation of stop words:
filtered_sent=[]

#  "nlp" Object is used to create documents with linguistic annotations.
doc = nlp(text)

# %%
# filtering stop words
for word in doc:
    if word.is_stop==False:
        filtered_sent.append(word)
print("Filtered Sentence:",filtered_sent)
# Out:
# Filtered Sentence: [learning, data, science, ,, discouraged, !,
# , Challenges, setbacks, failures, ,, journey, ., got, !]

# %%
# Implementing lemmatization
lem = nlp("america american")
# finding lemma for each word
for word in lem:
    print(word.text, word.lemma_)
# Out:
# america america
# american american

# %%
# POS tagging

#  "nlp" Objectis used to create documents with linguistic annotations.
docs = nlp(u"All is well that ends well.")

for word in docs:
    print(word.text,word.pos_)
# Out:
# All DET
# is VERB
# well ADV
# that DET
# ends VERB
# well ADV
# . PUNCT

# %%
# for visualization of Entity detection importing displacy from spacy:

from spacy import displacy

nytimes = nlp(u"""New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases.

At least 285 people have contracted measles in the city since September, mostly in Brooklyn’s Williamsburg neighborhood. The order covers four Zip codes there, Mayor Bill de Blasio (D) said Tuesday.

The mandate orders all unvaccinated people in the area, including a concentration of Orthodox Jews, to receive inoculations, including for children as young as 6 months old. Anyone who resists could be fined up to $1,000.""")

entities = [(i, i.label_, i.label) for i in nytimes.ents]
entities
# Out:
# [(New York City, 'GPE', 384),
#  (Tuesday, 'DATE', 391),
#  (At least 285, 'CARDINAL', 397),
#  (September, 'DATE', 391),
#  (Brooklyn, 'GPE', 384),
#  (Williamsburg, 'GPE', 384),
#  (four, 'CARDINAL', 397),
#  (Bill de Blasio, 'PERSON', 380),
#  (Tuesday, 'DATE', 391),
#  (Orthodox Jews, 'NORP', 381),
#  (6 months old, 'DATE', 391),
#  (up to $1,000, 'MONEY', 394)]

# %%
displacy.render(nytimes, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases.</br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     At least 285
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people have contracted measles in the city since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     September
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , mostly in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Brooklyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Williamsburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  neighborhood. The order covers
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Zip codes there, Mayor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bill de Blasio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (D) said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>The mandate orders all unvaccinated people in the area, including a concentration of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Orthodox Jews
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , to receive inoculations, including for children as young as
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     6 months old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Anyone who resists could be fined
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     up to $1,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div>

# %%
# Depenency parsing is a language processing technique that allows us to better determine 
# the meaning of a sentence by analyzing how it’s constructed to determine how the 
# individual words relate to each other.

docp = nlp(" In pursuit of a wall, President Trump ran into one.")

for chunk in docp.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_,
          chunk.root.head.text)
# Out:
# pursuit pursuit pobj In
# a wall wall pobj of
# President Trump Trump nsubj ran

# %%
displacy.render(docp, style="dep", jupyter= True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="541ba4f91d9248bcbf099b9cb6feec6f-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">pursuit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">wall,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">ran</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">one.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-1" stroke-width="2px" d="M245,264.5 C245,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-2" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,266.5 L398.0,254.5 382.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-3" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-5" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-6" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-7" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-541ba4f91d9248bcbf099b9cb6feec6f-0-8" stroke-width="2px" d="M1470,264.5 C1470,177.0 1615.0,177.0 1615.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-541ba4f9

# %%
# Word Vector Representation
# A word vector is a numeric representation of a word that commuicates its relationship to other words.

mango = nlp(u'mango')
print(mango.vector.shape)
print(mango.vector)
# Out:
# (96,)
# [ 1.0466383  -1.5323697  -0.72177905 -2.4700649  -0.2715162   1.1589639
#   1.7113379  -0.31615403 -2.0978343   1.837553    1.4681302   2.728043
#  -2.3457408  -5.17184    -4.6110015  -0.21236466 -0.3029521   4.220028
#  -0.6813917   2.4016762  -1.9546705  -0.85086954  1.2456163   1.5107994
#   0.4684736   3.1612053   0.15542296  2.0598564   3.780035    4.6110964
#   0.6375268  -1.078107   -0.96647096 -1.3939928  -0.56914186  0.51434743
#   2.3150034  -0.93199825 -2.7970662  -0.8540115  -3.4250052   4.2857723
#   2.5058174  -2.2150877   0.7860181   3.496335   -0.62606215 -2.0213525
#  -4.47421     1.6821622  -6.0789204   0.22800982 -0.36950028 -4.5340714
#  -1.7978683  -2.080299    4.125556    3.1852438  -3.286446    1.0892276
#   1.017115    1.2736416  -0.10613725  3.5102775   1.1902348   0.05483437
#  -0.06298041  0.8280688   0.05514218  0.94817173 -0.49377063  1.1512338
#  -0.81374085 -1.6104267   1.8233354  -2.278403   -2.1321895   0.3029334
#  -1.4510616  -1.0584296  -3.5698352  -0.13046083 -0.2668339   1.7826645
#   0.4639858  -0.8389523  -0.02689964  2.316218    5.8155413  -0.45935947
#   4.368636    1.6603007  -3.1823301  -1.4959551  -0.5229269   1.3637555 ]

# %%
# Text Classification
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline

# %%
# Loading TSV file
df_amazon = pd.read_csv ("amazon_alexa.tsv", sep="\t")

# %%
# Top 5 records
df_amazon.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
# shape of dataframe
df_amazon.shape
# Out:
# (3150, 5)

# %%
# View data information
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 5 columns):
# rating              3150 non-null int64
# date                3150 non-null object
# variation           3150 non-null object
# verified_reviews    3150 non-null object
# feedback            3150 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 123.1+ KB

# %%
# Feedback Value count
df_amazon.feedback.value_counts()
# Out:
# 1    2893
# 0     257
# Name: feedback, dtype: int64

# %%
# Tokening the Data

# %%
import string
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS

# Create our list of punctuation marks
punctuations = string.punctuation

# %%
# Create our list of stopwords
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# %%
# Load English tokenizer, tagger, parser, NER and word vectors
parser = English()

# %%
# Creating our tokenizer function
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    mytokens = parser(sentence)

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [word.lemma_.lower().strip() if word.lemma_ !=
                "-PRON-" else word.lower_ for word in mytokens]

    # Removing stop words
    mytokens = [word for word in mytokens if word not in stop_words]
    
    #Removing punctuations
    mytokens = [word for word in mytokens if word not in punctuations]

    mytokens = ' '.join(mytokens)
    # return preprocessed list of tokens
    return mytokens

# %%
# Defining a Custom Transformer

# %% [markdown]
# To further clean our text data, we’ll also want to create a custom transformer for removing initial and end spaces and converting text into lower case. Here, we will create a custom predictors class wich inherits the TransformerMixin class. This class overrides the transform, fit and get_parrams methods. We’ll also create a clean_text() function that removes spaces and converts text into lowercase.

# %%
# Custom transformer using spaCy
class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        # Cleaning Text
        return [clean_text(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

    def get_params(self, deep=True):
        return {}

# Basic function to clean the text
def clean_text(text):
    # Removing spaces and converting text into lowercase
    return text.strip().lower()

# %% [markdown]
# Vectorization Feature Engineering (TF-IDF)

# %% [markdown]
# One tool we can use for doing this is called Bag of Words. BoW converts text into the matrix of occurrence of words within a given document. It focuses on whether given words occurred or not in the document, and it generates a matrix that we might see referred to as a BoW matrix or a document term matrix.
#
# We can generate a BoW matrix for our text data by using scikit-learn‘s CountVectorizer. In the code below, we’re telling CountVectorizer to use the custom spacy_tokenizer function we built as its tokenizer, and defining the ngram range we want.

# %%
# BoW converts text into the matrix of occurrence of words within a given document. 
bow_vector = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1))

# %%
tfidf_vector = TfidfVectorizer(tokenizer = spacy_tokenizer)

# %%
from sklearn.model_selection import train_test_split

X = df_amazon['verified_reviews'] # the features we want to analyze
ylabels = df_amazon['feedback'] # the labels, or answers, we want to test against

X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.3)

# %% [markdown]
# Creating a Pipeline and Generating the Model

# %%
# Logistic Regression Classifier
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# Create pipeline using Bag of Words
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', bow_vector),
                 ('classifier', classifier)])

# model generation
pipe.fit(X_train,y_train)
# Out:
# /anaconda3/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Pipeline(memory=None,
#      steps=[('cleaner', <__main__.predictors object at 0x11a8da748>), ('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram...penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])

# %% [markdown]
# Evaluating the Model

# %%
from sklearn import metrics
# Predicting with a test dataset
predicted = pipe.predict(X_test)

# Model Accuracy
print("Logistic Regression Accuracy:",metrics.accuracy_score(y_test, predicted))
print("Logistic Regression Precision:",metrics.precision_score(y_test, predicted))
print("Logistic Regression Recall:",metrics.recall_score(y_test, predicted))
# Out:
# Logistic Regression Accuracy: 0.9365079365079365
# Logistic Regression Precision: 0.9399563318777293
# Logistic Regression Recall: 0.9942263279445728

# %%
Obama_Speeches=pd.read_csv('Obama Speeches')

# %%
Obama_Speeches.head()
# Out:
#       candidate        date  \
# 0  Barack Obama  2004-07-27
# 1  Barack Obama  2007-02-10
# 2  Barack Obama  2007-03-02
# 3  Barack Obama  2007-03-04
# 4  Barack Obama  2007-04-23
#
#                                         speech title  \
# 0  Keynote Address at the 2004 Democratic Nationa...
# 1  Remarks Announcing Candidacy for President in ...
# 2       Remarks at the AIPAC Policy Forum in Chicago
# 3  Remarks at the Selma Voting Rights March Comme...
# 4   Remarks to the Chicago Council on Global Affairs
#
#                                                 text     party  won_nomination
# 0  On behalf of the great state of Illinois, cros...  Democrat               1
# 1  Let me begin by saying thanks to all you who'v...  Democrat               1
# 2  Thank you so much for your kind introduction a...  Democrat               1
# 3  Here today, I must begin because at the Unity ...  Democrat               1
# 4  Good morning. We all know that these are not t...  Democrat               1

# %%
Obama_Speeches['tokenized_text']=Obama_Speeches.text.apply(lambda x: spacy_tokenizer(x))

# %%
Obama_tokenized_text = [text for text in Obama_Speeches['tokenized_text']]

# %%
Obama_tokenized_text=' '.join(Obama_tokenized_text).split()

# %%
Obama_counts = Counter(Obama_tokenized_text)

# %%
Obama_common_words = [word[0] for word in Obama_counts.most_common(20)]

# %%
Obama_common_counts = [word[1] for word in Obama_counts.most_common(20)]

# %%
fig = plt.figure(figsize=(18,6))
sns.barplot(x=Obama_common_words, y=Obama_common_counts)
plt.title("Most Common Words used in the Obama's Speeches")
plt.show()

# %%
nlp.max_length = 10000000

# %%
Obama_text = [text for text in Obama_Speeches.text]

# %%
Obama_text=' '.join(Obama_text).strip()

# %%
Obama_ents=nlp(Obama_text).ents

# %%
entities = {}
# named entities
for ent in Obama_ents:
    # Print the entity text and its label
    if ent.text in entities:
        entities[ent.text] += 1
    else:
        entities[ent.text] = 1
result = sorted(entities.items(), key=lambda kv: kv[1], reverse=True)[:50]

# %%
print("top 10 entities {}".format(result))
fig = plt.figure(figsize=(12,18))

plt.barh(["\"{}\"".format(i[0]) for i in result], [i[1] for i in result])
plt.ylabel('named entity')
plt.xlabel('total')
plt.xticks(rotation='horizontal', fontsize=10)
plt.title("Top {} named entities".format(50))
plt.subplots_adjust(bottom=0.40)
plt.show()
plt.close()
# Out:
# top 10 entities [('America', 3708), ('American', 3068), ('Americans', 2007), ('one', 1398), ('Washington', 1332), ('Iraq', 1227), ('first', 1220), ('today', 940), ('the United States of America', 791), ('2008', 780), ('two', 772), ('the United States', 750), ('Congress', 741), ('Romney', 681), ('Republicans', 582), ('Four more years', 561), ('millions', 554), ('McCain', 551), ('Afghanistan', 525), ('John McCain', 482), ('second', 472), ('Ohio', 448), ('Democrats', 429), ('Michelle', 392), ('Medicare', 379), ('Iowa', 373), ('Republican', 342), ('Earth', 335), ('Bush', 329), ('Chicago', 303), ('Obama', 263), ('Iran', 255), ('Florida', 253), ('China', 247), ('Clinton', 247), ('the 21st century', 246), ('Israel', 233), ('half', 233), ('First', 231), ('State', 228), ('Senate', 225), ('Bill Clinton', 216), ('three', 209), ('a decade', 207), ('George Bush', 205), ('Democratic', 200), ('Virginia', 197), ('tonight', 196), ('the Great Depression', 195), ('Illinois', 182)]

# %%
for ent in Obama_ents:
    print(ent.text, ent.label_,ent.lemma_)
# Out:
# Illinois GPE Illinois
# Lincoln ORG Lincoln
# Tonight TIME tonight
# Kenya GPE Kenya
# Two-thirds CARDINAL two - third
# Army ORG Army
# 88% PERCENT 88 %
# the National Guard ORG the National Guard
# Afghanistan GPE Afghanistan
# Iraq GPE Iraq
# two CARDINAL two
# 65,000 CARDINAL 65,000
# Army ORG Army
# 27,000 CARDINAL 27,000
# Marines NORP Marines
# first ORDINAL first
# the National Guard ORG the National Guard
# A 21st century DATE a 21st century
# today DATE today
# Baghdad GPE Baghdad
# Arabic LANGUAGE Arabic
# less than 1% PERCENT less than 1 %
# American NORP american
# Arabic LANGUAGE Arabic
# Mandarin LANGUAGE Mandarin
# Hindi PERSON Hindi
# Urdu GPE Urdu
# Korean NORP korean
# Rumsfeld PERSON Rumsfeld
# Army ORG Army
# Army ORG Army
# Army ORG Army
# George H.W. Bush PERSON George H.W. Bush
# Operation Desert Storm EVENT Operation Desert Storm
# American NORP american
# American NORP american
# third ORDINAL third
# America GPE America
# Henry Kissinger PERSON Henry Kissinger
# George Shultz PERSON George Shultz
# Bill Perry PERSON Bill Perry
# Sam Nunn PERSON Sam Nunn
# today DATE today
# about 50 tons QUANTITY about 50 ton
# forty CARDINAL forty
# Soviet Union GPE Soviet Union
# about 15,000 to 16,000 CARDINAL about 15,000 to 16,000
# 40,000 CARDINAL 40,000
# 11 CARDINAL 11
# four years DATE four year
# Russia GPE Russia
# Russia GPE Russia
# Dick Lugar PERSON Dick Lugar
# the United States GPE the United States
# Iran GPE Iran
# North Korea's GPE North Korea 's
# America GPE America
# two CARDINAL two
# first ORDINAL first
# North Korea GPE North Korea
# Iran GPE Iran
# the UN Security Council ORG the UN Security Council
# Europe LOC Europe
# the Gulf States LOC the Gulf States
# nearly a dozen CARDINAL nearly a dozen
# the Middle East LOC the Middle East
# Syria GPE Syria
# Saudi Arabia GPE Saudi Arabia
# Iran GPE Iran
# the Nuclear Threat Initiative ORG the Nuclear Threat Initiative
# Warren Buffett PERSON Warren Buffett
# two CARDINAL two
# the United States GPE the United States
# $50 million MONEY $ 50 million
# Russia GPE Russia
# the United States GPE the United States
# Russia GPE Russia
# Bush PERSON Bush
# The United States GPE the United States
# Cold War EVENT Cold War
# Six years later DATE six year later
# Bush PERSON Bush
# the 21st century DATE the 21st century
# fourth ORDINAL fourth
# America GPE America
# the Second World War EVENT the Second World War
# America GPE America
# the Cold War EVENT the Cold War
# Harry Truman PERSON Harry Truman
# George Marshall PERSON George Marshall
# Today DATE today
# the United Nations ORG the United Nations
# the World Bank ORG the World Bank
# the last 15 years DATE the last 15 year
# NATO ORG NATO
# Cold War EVENT Cold War
# Today DATE today
# NATO ORG NATO
# Afghanistan GPE Afghanistan
# Dick Lugar PERSON Dick Lugar
# NATO ORG NATO
# NATO ORG NATO
# the 21st century DATE the 21st century
# Asia LOC Asia
# China GPE China
# the United States GPE the United States
# the United States GPE the United States
# the Six Party ORG the six Party
# Asia LOC Asia
# the 21st century DATE the 21st century
# one CARDINAL one
# 10% PERCENT 10 %
# 2050 DATE 2050
# more than 250 million CARDINAL more than 250 million
# the next fifty years DATE the next fifty year
# the last fifty DATE the last fifty
# Africa LOC Africa
# the Middle East LOC the Middle East
# South Asia LOC South Asia
# America GPE America
# America GPE America
# the United States GPE the United States
# the European Union ORG the European Union
# Russia GPE Russia
# China GPE China
# India GPE India
# nearly two-thirds CARDINAL nearly two - third
# $500 billion MONEY $ 500 billion
# 2050 DATE 2050
# American NORP american
# fifth ORDINAL fifth
# America GPE America
# tomorrow DATE tomorrow
# Al Qaeda's ORG Al Qaeda 's
# Afghanistan GPE Afghanistan
# Chechnya GPE Chechnya
# Britain GPE Britain
# Germany GPE Germany
# Algeria GPE Algeria
# Pakistan GPE Pakistan
# millions CARDINAL million
# Last summer DATE last summer
# the Horn of Africa's LOC the Horn of Africa 's
# Combined Joint Task Force ORG Combined Joint Task Force
# Camp Lemonier ORG Camp Lemonier
# Djibouti GPE Djibouti
# U.S. GPE U.S.
# four years ago DATE four year ago
# the Task Force ORG the Task Force
# Hunt PERSON Hunt
# the Task Force ORG the Task Force
# Dire Dawa PERSON Dire Dawa
# U.S. GPE U.S.
# Ethiopians NORP Ethiopians
# One CARDINAL one
# Navy ORG Navy
# at least 95 percent PERCENT at least 95 percent
# U.S. GPE U.S.
# the Task Force ORG the Task Force
# the last six years DATE the last six year
# America GPE America
# $50 billion MONEY $ 50 billion
# 2012 DATE 2012
# the last twenty years DATE the last twenty year
# U.S. GPE U.S.
# 2012 DATE 2012
# Tony Blair PERSON Tony Blair
# 2005 DATE 2005
# Gleneagles ORG Gleneagles
# two billion dollar MONEY two billion dollar
# Global Education Fund ORG Global Education Fund
# 9/11 CARDINAL 9/11
# Americans NORP Americans
# today DATE today
# U.S. GPE U.S.
# Camp Lemonier ORG Camp Lemonier
# one CARDINAL one
# $50 billion MONEY $ 50 billion
# less than one-half CARDINAL less than one - half
# last year DATE last year
# Pentagon ORG Pentagon
# Iraq GPE Iraq
# America GPE America
# Africa LOC Africa
# decades DATE decade
# America GPE America
# September morning TIME September morning
# more than five years ago DATE more than five year ago
# A 21st century DATE a 21st century
# Djibouti GPE Djibouti
# Kandahar GPE Kandahar
# eighty CARDINAL eighty
# American NORP american
# Americans NORP Americans
# Americans NORP Americans
# American NORP american
# American NORP american
# America GPE America
# American NORP american
# America GPE America
# Berliners PERSON berliner
# Asia LOC Asia
# American NORP american
# the Middle East LOC the Middle East
# America GPE America
# One CARDINAL one
# first ORDINAL first
# Kenya GPE Kenya
# more than thirty CARDINAL more than thirty
# America GPE America
# American NORP american
# American NORP american
# a little over two months DATE a little over two month
# a minute TIME a minute
# first ORDINAL first
# Chicago GPE Chicago
# just a year DATE just a year
# 12,000 MONEY 12,000
# Chicago GPE Chicago
# three years DATE three year
# Chicago GPE Chicago
# a few years DATE a few year
# Senate ORG Senate
# two CARDINAL two
# two CARDINAL two
# First ORDINAL first
# Barack Obama PERSON Barack Obama
# Alabama PERSON Alabama
# Yo Mama WORK_OF_ART Yo Mama
# Kenya GPE Kenya
# Kansas GPE Kansas
# second ORDINAL second
# 2.5 million barrels QUANTITY 2.5 million barrel
# the Middle East LOC the Middle East
# 50 million CARDINAL 50 million
# Detroit GPE Detroit
# years DATE year
# American NORP american
# millions CARDINAL million
# thousands CARDINAL thousand
# billions CARDINAL billion
# the last few years DATE the last few year
# 27.5 miles QUANTITY 27.5 mile
# two decades DATE two decade
# China GPE China
# Japan GPE Japan
# Japanese NORP japanese
# 45 miles QUANTITY 45 mile
# first ORDINAL first
# 1931 DATE 1931
# Toyota ORG Toyota
# General Motors ORG General Motors
# two CARDINAL two
# Today DATE today
# two CARDINAL two
# American NORP american
# one CARDINAL one
# America GPE America
# one CARDINAL one
# ten CARDINAL ten
# American NORP american
# American NORP American
# America GPE America
# America GPE America
# first ORDINAL first
# Republicans NORP Republicans
# Democrats NORP Democrats
# years DATE year
# Fred Smith PERSON Fred Smith
# Federal Express ORG Federal Express
# P.X. Kelley PERSON P.X. Kelley
# American NORP american
# four percent PERCENT four percent
# approximately one mile QUANTITY approximately one mile
# The National Academy of Sciences ORG the National Academy of Sciences
# today DATE today
# the National Highway Traffic and Safety Administration ORG the National Highway Traffic and Safety Administration
# U.S. GPE U.S.
# one CARDINAL one
# the 21st century DATE the 21st century
# one CARDINAL one
# years DATE year
# 1,500 MONEY 1,500
# GM ORG GM
# American NORP american
# a few hundred extra dollars MONEY a few hundred extra dollar
# Detroit GPE Detroit
# second ORDINAL second
# Entrepreneurs ORG entrepreneur
# America GPE America
# the U.S. Senate ORG the U.S. Senate
# 100 MONEY 100
# E85 PRODUCT E85
# a National Low-Carbon Fuel Standard ORG a National Low - Carbon Fuel Standard
# Arnold Schwarzenegger PERSON Arnold Schwarzenegger
# California GPE California
# just a few months ago DATE just a few month ago
# 2010 DATE 2010
# one percent PERCENT one percent
# two CARDINAL two
# today DATE today
# a National Low-Carbon Fuel Standard - will ORG a National Low - Carbon Fuel Standard - will
# decades DATE decade
# 2.5 million fewer barrels QUANTITY 2.5 million few barrel
# 50 million CARDINAL 50 million
# 2020 DATE 2020
# that year DATE that year
# over $50 billion MONEY over $ 50 billion
# Americans NORP Americans
# the days and months DATE the day and month
# September 11th EVENT September 11th
# Americans NORP Americans
# the Greatest Generation PERSON the Greatest Generation
# Franklin Roosevelt PERSON Franklin Roosevelt
# so many years ago DATE so many year ago
# Detroit GPE Detroit
# Texas GPE Texas
# New Jersey GPE New Jersey
# California GPE California
# Washington GPE Washington
# American NORP american
# Congress ORG Congress
# American NORP american
# LeBlanc PERSON LeBlanc
# the Board of Trustees ORG the Board of Trustees
# Southern New Hampshire University ORG Southern New Hampshire University
# first ORDINAL first
# years DATE year
# years DATE year
# Bible WORK_OF_ART Bible
# Corinthians NORP Corinthians
# 13:11 DATE 13:11
# days DATE day
# today DATE today
# first ORDINAL first
# first ORDINAL first
# thirty and forty and CARDINAL thirty and forty and
# today DATE today
# Paris Hilton ORG Paris Hilton
# Darfur GPE Darfur
# New Orleans GPE New Orleans
# American NORP american
# one CARDINAL one
# three CARDINAL three
# today DATE today
# first ORDINAL first
# my first year DATE -PRON- first year
# a particularly long night TIME a particularly long night
# the next day DATE the next day
# one CARDINAL one
# Barack PERSON Barack
# first ORDINAL first
# Americans NORP Americans
# half CARDINAL half
# second ORDINAL second
# Chicago GPE Chicago
# the early 80s DATE the early 80
# 12,000 MONEY 12,000
# 1,000 MONEY 1,000
# Chicago GPE Chicago
# Chicago GPE Chicago
# second ORDINAL second
# a few minutes TIME a few minute
# third ORDINAL third
# Chicago GPE Chicago
# weeks DATE week
# first ORDINAL first
# The night TIME the night
# Thirteen CARDINAL thirteen
# that night TIME that night
# two years DATE two year
# third ORDINAL third
# that day DATE that day
# one CARDINAL one
# one CARDINAL one
# one CARDINAL one
# today DATE today
# Richard Komi PERSON Richard Komi
# thousands of miles QUANTITY thousand of mile
# Southern Nigeria LOC Southern Nigeria
# the United States GPE the United States
# SNHU ORG SNHU
# Africa LOC Africa
# Richard Komi PERSON Richard Komi
# today DATE today
# America GPE America
# decades DATE decade
# Americans NORP Americans
# Darfur GPE Darfur
# today DATE today
# America GPE America
# Richard Komi PERSON Richard Komi
# thousands upon thousands CARDINAL thousand upon thousand
# first ORDINAL first
# just a few hours TIME just a few hour
# hundreds CARDINAL hundred
# Saturday DATE Saturday
# New Hampshire GPE New Hampshire
# Americans NORP Americans
# the Civil Rights Movement ORG the Civil Rights Movement
# the day DATE the day
# four CARDINAL four
# Georgia GPE Georgia
# Alabama GPE Alabama
# Mississippi GPE Mississippi
# Freedom Ride FAC Freedom Ride
# South LOC South
# America GPE America
# the University of Iowa ORG the University of Iowa
# Amy PERSON Amy
# Lane PERSON Lane
# today DATE today
# A few hours TIME a few hour
# Amy PERSON Amy
# Lane PERSON Lane
# first ORDINAL first
# Iowa GPE Iowa
# every day DATE every day
# hundreds CARDINAL hundred
# today DATE today
# Lane PERSON Lane
# twenty-one years old DATE twenty - one year old
# Seventeen years later DATE seventeen year later
# three CARDINAL three
# 1,000 MONEY 1,000
# hundreds of dollars MONEY hundred of dollar
# Amy PERSON Amy
# Lane PERSON Lane
# forty percent PERCENT forty percent
# annual DATE annual
# Amy PERSON Amy
# the day DATE the day
# one CARDINAL one
# Amy PERSON Amy
# Earth LOC Earth
# American NORP american
# the past few months DATE the past few month
# Amy PERSON Amy
# New Hampshire GPE New Hampshire
# Iowa GPE Iowa
# decades DATE decade
# Washington GPE Washington
# one CARDINAL one
# Democrats NORP Democrats
# Republicans NORP Republicans
# 45 million CARDINAL 45 million
# Americans NORP Americans
# nearly 90% PERCENT nearly 90 %
# the past six years DATE the past six year
# four CARDINAL four
# Ami PERSON Ami
# Lane PERSON Lane
# nearly half CARDINAL nearly half
# Iowans NORP Iowans
# 11 million CARDINAL 11 million
# Americans NORP Americans
# more than a quarter DATE more than a quarter
# last year DATE last year
# over half CARDINAL over half
# Over half CARDINAL over half
# America GPE America
# GM ORG GM
# Ford ORG Ford
# GM ORG GM
# seven CARDINAL seven
# Japanese NORP japanese
# Americans NORP Americans
# 922 MONEY 922
# one CARDINAL one
# One CARDINAL one
# every four dollars MONEY every four dollar
# the last century DATE the last century
# Each year DATE each year
# 100,000 CARDINAL 100,000
# Americans NORP Americans
# $100 billion MONEY $ 100 billion
# thousands CARDINAL thousand
# billions of dollars MONEY billion of dollar
# Amy PERSON Amy
# Lane PERSON Lane
# Bush PERSON Bush
# second ORDINAL second
# 2006 DATE 2006
# five CARDINAL five
# fifty CARDINAL fifty
# One CARDINAL one
# $125 million MONEY $ 125 million
# over $1 billion MONEY over $ 1 billion
# more than $1 billion MONEY more than $ 1 billion
# the last ten years DATE the last ten year
# American NORP American
# Washington GPE Washington
# American NORP American
# millions CARDINAL million
# Americans NORP Americans
# Amy PERSON Amy
# Lane PERSON Lane
# yesterday DATE yesterday
# the early nineties DATE the early ninety
# Massachusetts GPE Massachusetts
# California GPE California
# Democratic NORP democratic
# Republican NORP republican
# Washington GPE Washington
# Illinois GPE Illinois
# Republicans NORP Republicans
# Democrats NORP Democrats
# 20,000 CARDINAL 20,000
# 65,000 CARDINAL 65,000
# Medicaid ORG Medicaid
# annual DATE annual
# Illinois GPE Illinois
# today DATE today
# first ORDINAL first
# first ORDINAL first
# Today DATE today
# American NORP American
# as much as $2500 MONEY as much as $ 2500
# second ORDINAL second
# American NORP American
# one CARDINAL one
# 45 million CARDINAL 45 million
# Americans NORP Americans
# Iowa GPE Iowa
# Washington GPE Washington
# today DATE today
# Bush PERSON Bush
# Americans NORP Americans
# Today DATE today
# second ORDINAL second
# five CARDINAL five
# the 21st century DATE the 21st century
# American NORP american
# up to $2500 MONEY up to $ 2500
# First ORDINAL first
# two CARDINAL two
# ten CARDINAL ten
# more than eighty percent PERCENT more than eighty percent
# Second ORDINAL second
# first ORDINAL first
# today DATE today
# less than four cents MONEY less than four cent
# eighty percent PERCENT eighty percent
# annual DATE annual
# today DATE today
# Third ORDINAL third
# up to $100 billion MONEY up to $ 100 billion
# One CARDINAL one
# Pennsylvania GPE Pennsylvania
# Medicare ORG Medicare
# $1 billion MONEY $ 1 billion
# today DATE today
# hundreds CARDINAL hundred
# hundreds of thousands of dollars MONEY hundred of thousand of dollar
# every year DATE every year
# Illinois GPE Illinois
# Fourth ORDINAL fourth
# a 20th century DATE a 20th century
# a 21st century DATE a 21st century
# billions CARDINAL billion
# the Veterans Administration ORG the Veterans Administration
# nine dollars MONEY nine dollar
# twenty-five dollars MONEY twenty - five dollar
# billions and billions of dollars MONEY billion and billion of dollar
# the years DATE the year
# Americans NORP Americans
# America GPE America
# Europe LOC Europe
# Canada GPE Canada
# the last ten years DATE the last ten year
# four hundred CARDINAL four hundred
# Iowa GPE Iowa
# three CARDINAL three
# more than three-quarters CARDINAL more than three - quarter
# America GPE America
# first ORDINAL first
# thousands CARDINAL thousand
# Amy PERSON Amy
# Lane PERSON Lane
# decades DATE decade
# American NORP american
# Half a century ago DATE half a century ago
# America GPE America
# millions CARDINAL million
# Americans NORP Americans
# third ORDINAL third
# Americans NORP Americans
# age 30 DATE age 30
# Fraser ORG Fraser
# Marian NORP Marian
# Fraser Robinson PERSON Fraser Robinson
# Michelle PERSON Michelle
# Craig PERSON Craig
# Princeton PERSON Princeton
# only two years old DATE only two year old
# one CARDINAL one
# the 1970s DATE the 1970
# the month DATE the month
# today DATE today
# Michelle PERSON Michelle
# America GPE America
# today DATE today
# Iraq GPE Iraq
# Afghanistan GPE Afghanistan
# ...
# the span of minutes TIME the span of minute
# Congress ORG Congress
# Nancy Pelosi PERSON Nancy Pelosi
# House ORG House
# the 1960s DATE the 1960
# Nancy Pelosi PERSON Nancy Pelosi
# Washington GPE Washington
# Washington GPE Washington
# Washington GPE Washington
# Steven PERSON Steven
# today DATE today
# today DATE today
# Carol PERSON Carol
# Hank PERSON Hank
# Goldberg PRODUCT Goldberg
# Goldberg PRODUCT Goldberg
# Eli Segal's ORG Eli Segal 's
# Eli ORG Eli
# American NORP American
# so many years DATE so many year
# Michelle PERSON Michelle
# the last 8 years DATE the last 8 year
# 8 years ago DATE 8 year ago
# more than half CARDINAL more than half
# 20 million CARDINAL 20 million
# American NORP american
# the end of the month DATE the end of the month
# Congress ORG Congress
# 200 CARDINAL 200
# first ORDINAL first
# the Middle East LOC the Middle East
# the Oval Office ORG the Oval Office
# Hillary Clinton PERSON Hillary Clinton
# Philadelphia GPE Philadelphia
# Joe Biden PERSON Joe Biden
# Michelle PERSON Michelle
# Hillary PERSON Hillary
# many years DATE many year
# Democrat NORP Democrat
# Democratic NORP democratic
# Hillary PERSON Hillary
# American NORP american
# millions CARDINAL million
# billions CARDINAL billion
# Hillary PERSON Hillary
# decades DATE decade
# Hillary PERSON Hillary
# American NORP american
# the day DATE the day
# Democrats NORP Democrats
# about 3 months ago DATE about 3 month ago
# Commerce ORG Commerce
# two CARDINAL two
# Hillary PERSON Hillary
# the United States GPE the United States
# 80 days DATE 80 day
# millions CARDINAL million
# 80 days DATE 80 day
# the White House ORG the White House
# Hillary PERSON Hillary
# every single day DATE every single day
# 80 days DATE 80 day
# 80 days DATE 80 day
# Philadelphia GPE Philadelphia
# Earth LOC Earth
# Jim PERSON Jim
# Crystal ORG Crystal
# First ORDINAL first
# Ben Ray Luján PERSON Ben Ray Luján
# Nancy Pelosi PERSON Nancy Pelosi
# New York's GPE New York 's
# Steve Israel PERSON Steve Israel
# Steve PERSON Steve
# Jim PERSON Jim
# Census PERSON Census
# today DATE today
# Jason Furman PERSON Jason Furman
# the Super Bowl EVENT the Super Bowl
# Census ORG Census
# a Super Bowl EVENT a Super Bowl
# each year DATE each year
# last year DATE last year
# over 5 percent PERCENT over 5 percent
# Americans NORP Americans
# Americans NORP Americans
# last year DATE last year
# 1968 DATE 1968
# the United States GPE the United States
# Jim PERSON Jim
# a previous decade DATE a previous decade
# the Great Depression EVENT the Great Depression
# 1929 DATE 1929
# the Great Depression EVENT the Great Depression
# Congress ORG Congress
# one CARDINAL one
# one CARDINAL one
# millions CARDINAL million
# Americans NORP Americans
# Americans NORP Americans
# Republican NORP republican
# America GPE America
# Ted PERSON Ted
# Donald Trump PERSON Donald Trump
# last minute TIME last minute
# the United States Senate GPE the United States Senate
# American NORP american
# the 11th hour TIME the 11th hour
# Russia GPE Russia
# Vladimir Putin PERSON Vladimir Putin
# KGB ORG KGB
# Democrat NORP Democrat
# American NORP american
# two CARDINAL two
# Republican Party ORG Republican Party
# Democratic Party ORG Democratic Party
# Ted PERSON Ted
# years DATE year
# the State GPE the State
# Ohio GPE Ohio
# hundreds of thousands CARDINAL hundred of thousand
# Ohio GPE Ohio
# Casablanca WORK_OF_ART Casablanca
# Casablanca WORK_OF_ART Casablanca
# Humphrey Bogart PERSON Humphrey Bogart
# Donald Trump PERSON Donald Trump
# Republican NORP republican
# Republicans NORP Republicans
# 80 cents MONEY 80 cent
# Donald Trump PERSON Donald Trump
# Democrats NORP Democrats
# Democrats NORP Democrats
# one CARDINAL one
# America GPE America
# November DATE November
# election year DATE election year
# 2008 DATE 2008
# 2012 DATE 2012
# these 8 years DATE these 8 year
# 50 CARDINAL 50
# States GPE States
# the Democratic Party ORG the Democratic Party
# Democratic Party ORG Democratic Party
# the Democratic Party ORG the Democratic Party
# The Democratic Party ORG the Democratic Party
# The Democratic Party ORG the Democratic Party
# The Democratic Party ORG the Democratic Party
# the Democratic Party ORG the Democratic Party
# Ted Strickland PERSON Ted Strickland
# Ohio GPE Ohio
# Hillary Clinton PERSON Hillary Clinton
# the United States GPE the United States
# Earth LOC Earth
# these United States GPE these United States
# Ohio GPE Ohio
# God PERSON God
# God PERSON God
# the United States of America GPE the United States of America
# Christine PERSON Christine
# first ORDINAL first
# Senate ORG Senate
# House ORG House
# Senate ORG Senate
# the United States GPE the United States
# the House of Representatives ORG the House of Representatives
# Nancy Pelosi PERSON Nancy Pelosi
# Congress ORG Congress
# first ORDINAL first
# Ben Ray Luján PERSON Ben Ray Luján
# DCCC ORG dccc
# one CARDINAL one
# State of California ORG State of California
# Susie Davis PERSON Susie Davis
# Scott Peters PERSON Scott Peters
# Christine PERSON Christine
# 32 years DATE 32 year
# the Marine Corps ORG the Marine Corps
# Congress—Doug Applegate ORG Congress — Doug Applegate
# one CARDINAL one
# Nevada GPE Nevada
# the 8 years DATE the 8 year
# 15 million CARDINAL 15 million
# half CARDINAL half
# Last year DATE last year
# a single year DATE a single year
# 1968 DATE 1968
# 401(k)s CARDINAL 401(k)s
# well over 100,000 CARDINAL well over 100,000
# Iraq GPE Iraq
# Afghanistan GPE Afghanistan
# bin Laden PERSON bin Laden
# ISIL ORG ISIL
# Latino PERSON Latino
# African Americans NORP African Americans
# 20 million CARDINAL 20 million
# the White House ORG the White House
# the first 2 years DATE the first 2 year
# American NORP american
# Pell PERSON Pell
# millions CARDINAL million
# the House of Representatives ORG the House of Representatives
# the Affordable Care Act LAW the Affordable Care Act
# 20 years from now DATE 20 year from now
# 30 years from now DATE 30 year from now
# 50 years from now DATE 50 year from now
# Nancy Pelosi PERSON Nancy Pelosi
# Congress ORG Congress
# this year DATE this year
# the Paris Agreement ORG the Paris Agreement
# two CARDINAL two
# Congress ORG Congress
# the House of Representatives ORG the House of Representatives
# Senate ORG Senate
# Republicans NORP Republicans
# the last 2 years DATE the last 2 year
# the House of Representatives ORG the House of Representatives
# Republicans NORP Republicans
# 4 years DATE 4 year
# the last 2 years DATE the last 2 year
# Nancy PERSON Nancy
# American NORP american
# Michelle PERSON Michelle
# Joe Biden PERSON Joe Biden
# Hillary Clinton PERSON Hillary Clinton
# Congress ORG Congress
# Doug Applegate PERSON Doug Applegate
# Darrell Issa ORG Darrell Issa
# Doug [Darrell PERSON Doug [ Darrell
# White House ORG White House
# Issa PERSON Issa
# the United States Congress ORG the United States Congress
# Trump ORG Trump
# Donald Trump PERSON Donald Trump
# Darrell Issa— ORG Darrell Issa —
# Doug PERSON Doug
# Darrell Issa PERSON Darrell Issa
# Trump ORG Trump
# Trump ORG Trump
# Christmas DATE Christmas
# Republican NORP republican
# Michele Bachmann PERSON Michele Bachmann
# one evening TIME one evening
# Muslim NORP Muslim
# Doug PERSON Doug
# Congress ORG Congress
# Congress ORG Congress
# Donald Trump PERSON Donald Trump
# the Republican Party ORG the Republican Party
# Donald Trump PERSON Donald Trump
# the House of Representatives ORG the House of Representatives
# Nancy PERSON Nancy
# Susan PERSON Susan
# Scott PERSON Scott
# Trump ORG Trump
# the House of Representatives ORG the House of Representatives
# The Freedom Caucus ORG the Freedom Caucus
# the House of Representatives ORG the House of Representatives
# Vegas GPE Vegas
# Donald Trump PERSON Donald Trump
# Government ORG Government
# Congress ORG Congress
# Nancy Pelosi PERSON Nancy Pelosi
# House ORG House
# Nancy PERSON Nancy
# American NORP american

# %%
# TweetMiner function from Mike Roman


class TweetMiner(object):

    def __init__(self, api, result_limit=20):

        self.api = api
        self.result_limit = result_limit

    def mine_user_tweets(self, user="HillaryClinton", mine_retweets=False, max_pages=20):

        data = []
        last_tweet_id = False
        page = 1

        while page <= max_pages:

            if last_tweet_id:
                statuses = self.api.GetUserTimeline(
                    screen_name=user, count=self.result_limit, max_id=last_tweet_id - 1, include_rts=mine_retweets)
                statuses = [_.AsDict() for _ in statuses]
            else:
                statuses = self.api.GetUserTimeline(
                    screen_name=user, count=self.result_limit, include_rts=mine_retweets)
                statuses = [_.AsDict() for _ in statuses]

            for item in statuses:
                # Using try except here.
                # When retweets = 0 we get an error (GetUserTimeline fails to create a key, 'retweet_count')
                try:
                    mined = {
                        'tweet_id':        item['id'],
                        'handle':          item['user']['screen_name'],
                        'retweet_count':   item['retweet_count'],
                        'text':            item['full_text'],
                        'mined_at':        datetime.datetime.now(),
                        'created_at':      item['created_at'],
                    }

                except:
                    mined = {
                        'tweet_id':        item['id'],
                        'handle':          item['user']['screen_name'],
                        'retweet_count':   0,
                        'text':            item['full_text'],
                        'mined_at':        datetime.datetime.now(),
                        'created_at':      item['created_at'],
                    }

                last_tweet_id = item['id']
                data.append(mined)

            page += 1

        return data

# %%
punctuations
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
